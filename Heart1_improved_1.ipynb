# %% [markdown]
# # Heart Dataset

# %%
# Importing Important libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import Normalize
from sklearn.metrics import accuracy_score , confusion_matrix , precision_score , f1_score

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Collection

# %% [markdown]
# #### 1. Import Dataset

# %%
df = pd.read_csv("Heart.csv")
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ####  2. Finding Head

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %% [markdown]
# ####  3. Finding Tail

# %%
df.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %% [markdown]
# ####  4. Finding Type

# %%
print(f"Data Type is : {type(df)}")
# Out:
# Data Type is : <class 'pandas.DataFrame'>

# %% [markdown]
# #### 5. Finding Data Type For Each Columns

# %%
df.dtypes
# Out:
# HeartDisease            str
# BMI                 float64
# Smoking                 str
# AlcoholDrinking         str
# Stroke                  str
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking             str
# Sex                     str
# AgeCategory             str
# Race                    str
# Diabetic                str
# PhysicalActivity        str
# GenHealth               str
# SleepTime           float64
# Asthma                  str
# KidneyDisease           str
# SkinCancer              str
# dtype: object

# %% [markdown]
# #### 6. Finding Random Sample From Dataset

# %%
df.sample()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 268036           No  16.83      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex AgeCategory   Race Diabetic  \
# 268036           0.0          No  Female       70-74  White       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 268036              Yes  Very good        6.0     No            No        Yes

# %% [markdown]
# #### 7. Finding Summary of Dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  str
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  str
#  3   AlcoholDrinking   319795 non-null  str
#  4   Stroke            319795 non-null  str
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  str
#  8   Sex               319795 non-null  str
#  9   AgeCategory       319795 non-null  str
#  10  Race              319795 non-null  str
#  11  Diabetic          319795 non-null  str
#  12  PhysicalActivity  319795 non-null  str
#  13  GenHealth         319795 non-null  str
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  str
#  16  KidneyDisease     319795 non-null  str
# ...

# %% [markdown]
# #### 8. Finding All Column name mabs

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='str')

# %% [markdown]
# #### 9. Finding Out the Shape of Dataset

# %%
print(f"There are total rows and columns is : {df.shape}")
# Out:
# There are total rows and columns is : (319795, 18)

# %% [markdown]
# #### 10. Finding out Description of Dataset

# %%
df.describe(include="object")
# Out:
#        HeartDisease Smoking AlcoholDrinking  Stroke DiffWalking     Sex  \
# count        319795  319795          319795  319795      319795  319795
# unique            2       2               2       2           2       2
# top              No      No              No      No          No  Female
# freq         292422  187887          298018  307726      275385  167805
#
#        AgeCategory    Race Diabetic PhysicalActivity  GenHealth  Asthma  \
# count       319795  319795   319795           319795     319795  319795
# unique          13       6        4                2          5       2
# top          65-69   White       No              Yes  Very good      No
# freq         34151  245212   269653           247957     113858  276923
#
#        KidneyDisease SkinCancer
# count         319795     319795
# unique             2          2
# top               No         No
# freq          308016     289976

# %%
df.describe(include="number")
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %% [markdown]
# #### 11. Finding Null Values

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %% [markdown]
# #### 12. Finding Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(18078)

# %% [markdown]
# #### 13. Removing Duplicate Values

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### 14. Checking Target imbalance

# %%
# Count each class
class_counts = df['HeartDisease'].value_counts()
print("Class Distribution:\n", class_counts)

# Check percentage distribution
class_percent = df['HeartDisease'].value_counts(normalize=True) * 100
print("\nClass Percentage (%):\n", class_percent.round(2))

# Identify majority class percentage
max_percent = class_percent.max()

# Print imbalance status
if max_percent > 80:
    print("\nStatus: Highly Imbalanced Dataset")
elif max_percent > 60:
    print("\nStatus: Moderately Imbalanced Dataset")
else:
    print("\nStatus: Balanced Dataset")
# Out:
# Class Distribution:
#  HeartDisease
# No     274456
# Yes     27261
# Name: count, dtype: int64
#
# Class Percentage (%):
#  HeartDisease
# No     90.96
# Yes     9.04
# Name: proportion, dtype: float64
#
# Status: Highly Imbalanced Dataset

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# #### Data Quality Check

# %%
print("\n=== DATA QUALITY ASSESMENT ===")

# Check for missing values
print("\nMissing Values:")
missing_data = df.isnull().sum()
print( missing_data[ missing_data>0 ] )

# Check for duplicates
print(f"\nDuplicate Rows : {df.duplicated().sum()}")
# Out:
# === DATA QUALITY ASSESMENT ===
#
# Missing Values:
# Series([], dtype: int64)
#
# Duplicate Rows : 0

# %% [markdown]
# # EDA

# %% [markdown]
# ### UNIVARIENT ANALYSIS

# %%
df_temp = df.copy()
df_temp['HeartDisease'] = df_temp['HeartDisease'].map({'No': 0, 'Yes': 1})

# %% [markdown]
# ##### Categorical Variables Analysis

# %%
print("\n=== CATEGORICAL VARIABLES ===\n")

categorical_cols = []
for col in df.select_dtypes(include='object').columns:
    if df[col].nunique() < 20:
        categorical_cols.append(col)
print(categorical_cols)

for col in categorical_cols:
    print(f"\n--- {col} ---")
    print(df[col].value_counts())

    # Visualization
    plt.figure(figsize=(8,4))

    # Count Plot
    plt.subplot(1,2,1)
    sns.countplot(x=df[col], palette="colorblind")
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=30)

    # Pie Chart
    plt.subplot(1,2,2)
    df[col].value_counts().plot(kind="pie", autopct="%1.1f%%", startangle=90)
    plt.title(f"Pie Chart of {col}")
    plt.ylabel("")

    plt.tight_layout()
    plt.show()
# Out:
# === CATEGORICAL VARIABLES ===
#
# ['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer']
#
# --- HeartDisease ---
# HeartDisease
# No     274456
# Yes     27261
# Name: count, dtype: int64
# --- Smoking ---
# Smoking
# No     174312
# Yes    127405
# Name: count, dtype: int64
# --- AlcoholDrinking ---
# AlcoholDrinking
# No     280136
# Yes     21581
# Name: count, dtype: int64
# --- Stroke ---
# Stroke
# No     289653
# Yes     12064
# Name: count, dtype: int64
# --- DiffWalking ---
# DiffWalking
# No     257362
# Yes     44355
# Name: count, dtype: int64
# --- Sex ---
# Sex
# Female    159671
# Male      142046
# Name: count, dtype: int64
# --- AgeCategory ---
# AgeCategory
# 65-69          31670
# 60-64          31219
# 70-74          29273
# 55-59          27610
# 50-54          23736
# 80 or older    23352
# 75-79          20713
# ...

# %% [markdown]
# ##### Numerical Variables Analysis

# %%
print("\n=== Numerical VARIABLES ===\n")

numerical_cols = []
for col in df.select_dtypes( include= ["number"] ).columns:
    numerical_cols.append(col)
print(numerical_cols)

for col in numerical_cols:
    print(f"\n--- { col } ---\n")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Median: {df[col].median():.2f}")
    print(f"Std Dev: {df[col].std():.2f}")
    print(f"Min: {df[col].min():.2f}")
    print(f"Max: {df[col].max():.2f}")

    # Visualization
    plt.figure( figsize=(8,4) )

     # Histogram
    plt.subplot(1,2,1)
    sns.histplot(df[col], bins=30, kde=True, color = "red")
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")

    # Boxplot
    plt.subplot(1,2,2)
    sns.boxplot(x=df[col], color = "blue")
    plt.title(f"Boxplot of {col}")
    
    plt.tight_layout()
    plt.show()
# Out:
# === Numerical VARIABLES ===
#
# ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']
#
# --- BMI ---
#
# Mean: 28.44
# Median: 27.41
# Std Dev: 6.47
# Min: 12.02
# Max: 94.85
# --- PhysicalHealth ---
#
# Mean: 3.57
# Median: 0.00
# Std Dev: 8.14
# Min: 0.00
# Max: 30.00
# --- MentalHealth ---
#
# Mean: 4.12
# Median: 0.00
# Std Dev: 8.13
# Min: 0.00
# Max: 30.00
# --- SleepTime ---
#
# Mean: 7.08
# Median: 7.00
# Std Dev: 1.47
# Min: 1.00
# Max: 24.00

# %% [markdown]
# ### BIVARIENT ANALYSIS

# %% [markdown]
# #### Numeric vs Target columns

# %%
print("\n=== BIVARIATE ANALYSIS (NUMERIC vs TARGET) ===\n")

target = "HeartDisease"

numerical_cols = []
for col in df_temp.select_dtypes( include= ["number"] ).columns:
    numerical_cols.append(col)
print(numerical_cols)

for col in numerical_cols:
    if col == target:
        continue
    print(f"\n--- {col} vs {target} ---\n")
    print(f"Correlation: {df_temp[col].corr(df_temp[target]):.3f}")
    print(f"Covariance: {df_temp[col].cov(df_temp[target]):.3f}")
    print(f"Mean {col}: {df_temp[col].mean():.2f}")
    print(f"Mean {target}: {df_temp[target].mean():.2f}")
    print(f"Std {col}: {df_temp[col].std():.2f}")
    print(f"Std {target}: {df_temp[target].std():.2f}")
    print(f"Observations: {len(df_temp)}")

    # Visualization
    plt.figure(figsize=(15,5))

    # Scatter plot
    plt.subplot(1,2,1)
    sns.scatterplot(x=df_temp[col], y=df_temp[target], color="purple")
    plt.title(f"{col} vs {target}")

    # Joint style plot
    plt.subplot(1,2,2)
    sns.regplot(x=df_temp[col], y=df_temp[target], color="red")
    plt.title(f"Trend: {col} vs {target}")
    plt.tight_layout()
    plt.show()

    # Joint Plot
    sns.jointplot(x=df_temp[col], y=df_temp[target], kind="scatter", height=6)
    plt.suptitle(f"Joint Plot: {col} vs {target}", y=1.02)
    plt.show()
# Out:
# === BIVARIATE ANALYSIS (NUMERIC vs TARGET) ===
#
# ['HeartDisease', 'BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']
#
# --- BMI vs HeartDisease ---
#
# Correlation: 0.047
# Covariance: 0.088
# Mean BMI: 28.44
# Mean HeartDisease: 0.09
# Std BMI: 6.47
# Std HeartDisease: 0.29
# Observations: 301717
# --- PhysicalHealth vs HeartDisease ---
#
# Correlation: 0.165
# Covariance: 0.386
# Mean PhysicalHealth: 3.57
# Mean HeartDisease: 0.09
# Std PhysicalHealth: 8.14
# Std HeartDisease: 0.29
# Observations: 301717
# --- MentalHealth vs HeartDisease ---
#
# Correlation: 0.021
# Covariance: 0.049
# Mean MentalHealth: 4.12
# Mean HeartDisease: 0.09
# Std MentalHealth: 8.13
# Std HeartDisease: 0.29
# Observations: 301717
# --- SleepTime vs HeartDisease ---
#
# Correlation: 0.011
# Covariance: 0.005
# Mean SleepTime: 7.08
# Mean HeartDisease: 0.09
# Std SleepTime: 1.47
# Std HeartDisease: 0.29
# Observations: 301717

# %% [markdown]
# #### Catgoical vs Target columns

# %%
print("\n=== BIVARIATE ANALYSIS (CATEGORICAL vs TARGET) ===\n")

target = "HeartDisease"

categorical_cols = []
for col in df_temp.select_dtypes(include='object').columns:
    if df_temp[col].nunique() < 20:
        categorical_cols.append(col)
print(categorical_cols)

for col in categorical_cols:
    # Visualization
    plt.figure(figsize=(10,4))

    plt.subplot(1,2,1)
    sns.boxplot(x=df_temp[col], y=df_temp[target])
    plt.title(f"{col} vs {target}")

    plt.subplot(1,2,2)
    sns.barplot(x=df_temp[col], y=df_temp[target])
    plt.title(f"Average {target} by {col}")

    plt.tight_layout()
    plt.show()
# Out:
# === BIVARIATE ANALYSIS (CATEGORICAL vs TARGET) ===
#
# ['Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer']

# %% [markdown]
# ### MULTIVARIENT ANALYSIS

# %%
# select numeric columns only
numeric_df = df_temp.select_dtypes(include=['number'])
# correlation matrix
corr_matrix = numeric_df.corr()

# correlation with target
target_corr = corr_matrix["HeartDisease"].sort_values(ascending=False)

print(target_corr)
# Out:
# HeartDisease      1.000000
# PhysicalHealth    0.165235
# BMI               0.047260
# MentalHealth      0.020913
# SleepTime         0.010834
# Name: HeartDisease, dtype: float64

# %%
# select numeric columns only
numeric_df = df.select_dtypes(include=['number'])

# Compute correlation
corr = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(
    df.sample(500),
    hue="HeartDisease",
    diag_kind="kde",
    corner=True
)

plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Outlier Handling

# %%
# ── Outlier Handling (IQR Winsorization) ──
# Applied to all continuous numerical features to reduce skew

def whisker(col):
    Q1 = col.quantile(0.25)
    Q3 = col.quantile(0.75)
    IQR = Q3 - Q1
    lb = Q1 - 1.5 * IQR
    ub = Q3 + 1.5 * IQR
    return lb, ub

# Apply Winsorization to all continuous features
continuous_cols = ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']

for col in continuous_cols:
    lb, ub = whisker(df[col])
    df[col] = np.where(df[col] < lb, lb, df[col])
    df[col] = np.where(df[col] > ub, ub, df[col])
    print(f'✅ {col}: capped to [{lb:.2f}, {ub:.2f}]')
# Out:
# ✅ BMI: capped to [12.95, 42.51]
# ✅ PhysicalHealth: capped to [-3.00, 5.00]
# ✅ MentalHealth: capped to [-4.50, 7.50]
# ✅ SleepTime: capped to [3.00, 11.00]

# %% [markdown]
# ### Encoding

# %%
# Identify categorical columns in the dataset
categorical_columns = df.select_dtypes(include=['object']).columns
print(f"\n                  ----Categorical Columns----                  \n\n{categorical_columns}")
print()

for i in categorical_columns:
    unique = df[i].unique()
    a = len(unique)
    print(f"---- {i} ----\n")
    print(f"The column has a total of : {a} unique values")
    print(f"{unique}\n")
# Out:
#                   ----Categorical Columns----
#
# Index(['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking',
#        'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity',
#        'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='str')
#
# ---- HeartDisease ----
#
# The column has a total of : 2 unique values
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# ---- Smoking ----
#
# The column has a total of : 2 unique values
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# ---- AlcoholDrinking ----
#
# The column has a total of : 2 unique values
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# ---- Stroke ----
#
# The column has a total of : 2 unique values
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# ---- DiffWalking ----
#
# The column has a total of : 2 unique values
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# ---- Sex ----
#
# ...

# %%
df = df.rename(
    columns={
        "Smoking" : "IS_Smoking",
        "AlcoholDrinking" : "Alcoholic",
        "Stroke" : "IS_Stroke",
        "DiffWalking" : "IS_DiffWalking",
        "Sex" : "IS_MALE",
        "PhysicalActivity" : "IS_PhysicalActivity",
        "Asthma" : "IS_Asthma",
        "KidneyDisease" : "IS_KidneyDisease",
        "SkinCancer" : "IS_SkinCancer",
        'Diabetic' : "IS_Diabetic"
    }
)
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'IS_Smoking', 'Alcoholic', 'IS_Stroke',
#        'PhysicalHealth', 'MentalHealth', 'IS_DiffWalking', 'IS_MALE',
#        'AgeCategory', 'Race', 'IS_Diabetic', 'IS_PhysicalActivity',
#        'GenHealth', 'SleepTime', 'IS_Asthma', 'IS_KidneyDisease',
#        'IS_SkinCancer'],
#       dtype='str')

# %%
# Applying Encoding

# One-hot encoding
df = pd.get_dummies(df, columns=["Race"],dtype="int")

# Label encoding
df["IS_MALE"] = df["IS_MALE"].map({
    "Male": 1,
    "Female": 0
})

df["IS_Smoking"] = df["IS_Smoking"].map({
    "Yes": 1,
    "No": 0
})

df["IS_Stroke"] = df["IS_Stroke"].map({
    "Yes": 1,
    "No": 0
})

df["IS_DiffWalking"] = df["IS_DiffWalking"].map({
    "Yes": 1,
    "No": 0
})

df["IS_PhysicalActivity"] = df["IS_PhysicalActivity"].map({
    "Yes": 1,
    "No": 0
})

df["IS_Asthma"] = df["IS_Asthma"].map({
    "Yes": 1,
    "No": 0
})

df["IS_KidneyDisease"] = df["IS_KidneyDisease"].map({
    "Yes": 1,
    "No": 0
})

df["IS_SkinCancer"] = df["IS_SkinCancer"].map({
    "Yes": 1,
    "No": 0
})

df["HeartDisease"] = df["HeartDisease"].map({
    "Yes": 1,
    "No": 0
})

df["Alcoholic"] = df["Alcoholic"].map({
    "Yes": 1,
    "No": 0
})

df["GenHealth"] = df["GenHealth"].map({
    "Poor": 0,
    "Fair": 1,
    "Good": 2,
    "Very good": 3,
    "Excellent": 4
})

# Ordinal encoding: captures gradual risk increase
df["IS_Diabetic"] = df["IS_Diabetic"].map({
    "No": 0,
    "No, borderline diabetes": 1,
    "Yes (during pregnancy)": 2,
    "Yes": 3
})

df["AgeCategory"] = df["AgeCategory"].map({
    "18-24": 0,
    "25-29": 1,
    "30-34": 2,
    "35-39": 3,
    "40-44": 4,
    "45-49": 5,
    "50-54": 6,
    "55-59": 7,
    "60-64": 8,
    "65-69": 9,
    "70-74": 10,
    "75-79": 11,
    "80 or older": 12
})

df.dtypes
# Out:
# HeartDisease                             int64
# BMI                                    float64
# IS_Smoking                               int64
# Alcoholic                                int64
# IS_Stroke                                int64
# PhysicalHealth                         float64
# MentalHealth                           float64
# IS_DiffWalking                           int64
# IS_MALE                                  int64
# AgeCategory                              int64
# IS_Diabetic                              int64
# IS_PhysicalActivity                      int64
# GenHealth                                int64
# SleepTime                              float64
# IS_Asthma                                int64
# IS_KidneyDisease                         int64
# IS_SkinCancer                            int64
# Race_American Indian/Alaskan Native      int64
# Race_Asian                               int64
# Race_Black                               int64
# ...

# %% [markdown]
# ### Feature Engineering

# %%
# ── Feature Engineering ──

# Overall health burden (physical + mental)
df["HealthScore"] = df["PhysicalHealth"] + df["MentalHealth"]

# Lifestyle risk (smoking + alcohol + no activity)
df["LifestyleRisk"] = df["IS_Smoking"] + df["Alcoholic"] + (1 - df["IS_PhysicalActivity"])

# Total number of co-morbidities
df["DiseaseCount"] = df["IS_Stroke"] + df["IS_Diabetic"] + df["IS_Asthma"] + df["IS_KidneyDisease"] + df["IS_SkinCancer"]

# Obesity indicator
df["BMIRisk"] = (df["BMI"] > 30).astype(int)

# Poor sleep indicator
df["SleepRisk"] = ((df["SleepTime"] < 5) | (df["SleepTime"] > 9)).astype(int)

# Age and disease interaction
df["Age_Disease"] = df["AgeCategory"] * df["DiseaseCount"]

# Final total risk score
# NOTE: MobilityRisk removed — it was a duplicate of IS_DiffWalking
df["TotalRisk"] = df["LifestyleRisk"] + df["DiseaseCount"] + df["BMIRisk"] + df["SleepRisk"] + df["IS_DiffWalking"]

# %%
df
# Out:
#         HeartDisease     BMI  IS_Smoking  Alcoholic  IS_Stroke  \
# 0                  0  16.600           1          0          0
# 1                  0  20.340           0          0          1
# 2                  0  26.580           1          0          0
# 3                  0  24.210           0          0          0
# 4                  0  23.710           0          0          0
# ...              ...     ...         ...        ...        ...
# 319790             1  27.410           1          0          0
# 319791             0  29.840           1          0          0
# 319792             0  24.240           0          0          0
# 319793             0  32.810           0          0          0
# 319794             0  42.505           0          0          0
#
#         PhysicalHealth  MentalHealth  IS_DiffWalking  IS_MALE  AgeCategory  \
# 0                  3.0           7.5               0        0            7
# ...

# %% [markdown]
# ### Feature Selection

# %%
import pandas as pd
import numpy as np

from sklearn.feature_selection import SelectKBest, f_classif, RFE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# -------------------------------
# Separate features and target
# -------------------------------
X = df.drop("HeartDisease", axis=1)
y = df["HeartDisease"]

# -------------------------------
# 1️⃣ Correlation with Target
# -------------------------------
corr = df.corr(numeric_only=True)["HeartDisease"].sort_values(ascending=False)
print("\nCorrelation with HeartDisease:")
print(corr)

# -------------------------------
# 2️⃣ SelectKBest (ANOVA F-test)
# -------------------------------
selector = SelectKBest(score_func=f_classif, k=10)
selector.fit(X, y)

kbest_features = X.columns[selector.get_support()]
print("\nTop features from SelectKBest:")
print(kbest_features)

# -------------------------------
# 3️⃣ Recursive Feature Elimination (RFE)
# -------------------------------
model = LogisticRegression(max_iter=1000)

rfe = RFE(model, n_features_to_select=10)
rfe.fit(X, y)

rfe_features = X.columns[rfe.support_]
print("\nTop features from RFE:")
print(rfe_features)

# -------------------------------
# 4️⃣ L1 Regularization (Lasso for classification)
# -------------------------------
lasso = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000)
lasso.fit(X, y)

lasso_features = X.columns[lasso.coef_[0] != 0]
print("\nImportant features from L1 Logistic Regression:")
print(lasso_features)

# -------------------------------
# 5️⃣ Random Forest Feature Importance
# -------------------------------
rf = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=42)
rf.fit(X, y)

importance = pd.Series(rf.feature_importances_, index=X.columns)
importance = importance.sort_values(ascending=False)

print("\nRandom Forest Feature Importance:")
print(importance)
# Out:
# Correlation with HeartDisease:
# HeartDisease                           1.000000
# Age_Disease                            0.270302
# TotalRisk                              0.261483
# DiseaseCount                           0.237632
# AgeCategory                            0.233432
# IS_DiffWalking                         0.201258
# IS_Stroke                              0.196835
# IS_Diabetic                            0.180826
# PhysicalHealth                         0.150958
# IS_KidneyDisease                       0.145197
# LifestyleRisk                          0.117576
# IS_Smoking                             0.107764
# IS_SkinCancer                          0.093317
# HealthScore                            0.077149
# SleepRisk                              0.070432
# IS_MALE                                0.070040
# BMI                                    0.054132
# BMIRisk                                0.044551
# IS_Asthma                              0.041444
# ...

# %%
# -------------------------------
# Get top 10 features from Random Forest
# -------------------------------
rf_top_features = importance.head(10).index

# -------------------------------
# Combine features from all methods
# -------------------------------
all_features = (
    list(kbest_features) +
    list(rfe_features) +
    list(lasso_features) +
    list(rf_top_features)
)

# -------------------------------
# Count frequency of each feature
# -------------------------------
feature_counts = pd.Series(all_features).value_counts()

# -------------------------------
# Display results
# -------------------------------
print("\nFeature Frequency Across Methods:")
print(feature_counts)
# Out:
# Feature Frequency Across Methods:
# GenHealth                              4
# IS_Stroke                              3
# PhysicalHealth                         3
# IS_DiffWalking                         3
# AgeCategory                            3
# IS_KidneyDisease                       3
# Age_Disease                            3
# TotalRisk                              3
# IS_MALE                                3
# IS_Diabetic                            2
# DiseaseCount                           2
# IS_Smoking                             2
# Alcoholic                              2
# IS_PhysicalActivity                    2
# Race_Asian                             2
# LifestyleRisk                          2
# BMI                                    2
# MentalHealth                           2
# SleepTime                              2
# HealthScore                            2
# IS_Asthma                              1
# IS_SkinCancer                          1
# ...

# %%
features = [
    "GenHealth",
    "IS_Stroke",
    "PhysicalHealth",
    "AgeCategory",
    "DiseaseCount",
    "Age_Disease",
    "TotalRisk",
    "IS_MALE",
    "IS_DiffWalking",
    "IS_Diabetic",
    "IS_Smoking",
    "IS_PhysicalActivity",
    "LifestyleRisk",
    "BMI",
    "MentalHealth",
    "SleepTime",
    "HealthScore",
]

# NOTE: MobilityRisk removed — duplicate of IS_DiffWalking
X = df[features]
y = df["HeartDisease"]
print(f'Feature matrix shape: {X.shape}')
X.head()
# Out:
# Feature matrix shape: (319795, 17)
#    GenHealth  IS_Stroke  PhysicalHealth  AgeCategory  DiseaseCount  \
# 0          3          0             3.0            7             5
# 1          3          1             0.0           12             1
# 2          1          0             5.0            9             4
# 3          2          0             0.0           11             1
# 4          3          0             5.0            4             0
#
#    Age_Disease  TotalRisk  IS_MALE  IS_DiffWalking  IS_Diabetic  IS_Smoking  \
# 0           35          6        0               0            3           1
# 1           12          1        0               0            0           0
# 2           36          5        1               0            3           1
# 3           11          2        0               0            0           0
# 4            0          1        0               1            0           0
#
# ...

# %% [markdown]
# ### Feature Scaling

# %%
# Identifying columns that may require feature scaling
numerical_features = df.select_dtypes(
    include=['int64','float64']).columns
numerical_features
# Out:
# Index(['HeartDisease', 'BMI', 'IS_Smoking', 'Alcoholic', 'IS_Stroke',
#        'PhysicalHealth', 'MentalHealth', 'IS_DiffWalking', 'IS_MALE',
#        'AgeCategory', 'IS_Diabetic', 'IS_PhysicalActivity', 'GenHealth',
#        'SleepTime', 'IS_Asthma', 'IS_KidneyDisease', 'IS_SkinCancer',
#        'Race_American Indian/Alaskan Native', 'Race_Asian', 'Race_Black',
#        'Race_Hispanic', 'Race_Other', 'Race_White', 'HealthScore',
#        'LifestyleRisk', 'DiseaseCount', 'BMIRisk', 'SleepRisk', 'Age_Disease',
#        'TotalRisk'],
#       dtype='str')

# %%
#numerical_features = ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']
# Check if feature scaling is necessary by examining
#the range of values for each numerical column
for i in features:
    column_range = df[i].max() - df[i].min()
    print(f'Range of {i}: {column_range}')
print("")
print("-------------------------------------------------")
print("")
print("We will aplly Standard Scale after train test split and befor the models that required scalling")
print("\n-------------------------------------------------")
# Out:
# Range of GenHealth: 4
# Range of IS_Stroke: 1
# Range of PhysicalHealth: 5.0
# Range of AgeCategory: 12
# Range of DiseaseCount: 7
# Range of Age_Disease: 84
# Range of TotalRisk: 12
# Range of IS_MALE: 1
# Range of IS_DiffWalking: 1
# Range of IS_Diabetic: 3
# Range of IS_Smoking: 1
# Range of IS_PhysicalActivity: 1
# Range of LifestyleRisk: 3
# Range of BMI: 29.560000000000002
# Range of MentalHealth: 7.5
# Range of SleepTime: 8.0
# Range of HealthScore: 12.5
#
# -------------------------------------------------
#
# We will aplly Standard Scale after train test split and befor the models that required scalling
#
# -------------------------------------------------

# %% [markdown]
# ### Train Test Split

# %%
#Splitting
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split( X , y , test_size=0.3 , random_state = 42 )# Model Training

# %% [markdown]
# # Models Training

# %%
# ===============================
# 🤖 MODEL SELECTION + TRAINING
# ===============================

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier

# Compute imbalance ratio for scale_pos_weight
neg_count = (y_train == 0).sum()
pos_count = (y_train == 1).sum()
imbalance_ratio = neg_count / pos_count
print(f'Imbalance ratio (neg/pos): {imbalance_ratio:.2f}')
# NOTE: KNN removed — too slow on 300K+ rows and sensitive to unscaled features

# ------------------------------
# 1. Select Models
# ------------------------------
models = {
    "Logistic Regression": LogisticRegression(class_weight='balanced', max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(max_depth=15, class_weight='balanced'),
    "Random Forest": RandomForestClassifier(class_weight='balanced'),
    "LightGBM": LGBMClassifier(
        n_estimators=300,
        learning_rate=0.05,
        scale_pos_weight=imbalance_ratio,  # native imbalance handling
    )
}

# ------------------------------
# 2. Train Models
# ------------------------------
trained_models = {}

for name, model in models.items():
    model.fit(x_train, y_train)
    trained_models[name] = model

print("✅ All models trained successfully!")
# Out:
# Imbalance ratio (neg/pos): 10.73
# [LightGBM] [Info] Number of positive: 19083, number of negative: 204773
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038969 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 401
# [LightGBM] [Info] Number of data points in the train set: 223856, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.085247 -> initscore=-2.373104
# [LightGBM] [Info] Start training from score -2.373104
# ✅ All models trained successfully!

# %% [markdown]
# # Models Evalution

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

results = {}

for name, model in models.items():

    # Prediction
    y_pred = model.predict(x_test)

    # Metrics
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')

    results[name] = {"Accuracy": acc, "F1 Score": f1}

    # Detailed Evaluation
    print(f"\n===== {name} =====")
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Final Comparison
print("\n=== FINAL RESULTS ===")
for model, scores in results.items():
    print(f"{model}: {scores}")
# Out:
# ===== Logistic Regression =====
# Confusion Matrix:
#  [[65060 22589]
#  [ 1830  6460]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84     87649
#            1       0.22      0.78      0.35      8290
#
#     accuracy                           0.75     95939
#    macro avg       0.60      0.76      0.59     95939
# weighted avg       0.91      0.75      0.80     95939
#
#
# ===== Decision Tree =====
# Confusion Matrix:
#  [[66978 20671]
#  [ 2906  5384]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.76      0.85     87649
#            1       0.21      0.65      0.31      8290
#
#     accuracy                           0.75     95939
#    macro avg       0.58      0.71      0.58     95939
# weighted avg       0.89      0.75      0.80     95939
#
#
# ===== Random Forest =====
# Confusion Matrix:
#  [[85168  2481]
# ...

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMClassifier

# Base model
lgbm = LGBMClassifier(class_weight='balanced', random_state=42)

# Parameter grid
params = {
    "num_leaves": [31, 50, 70],
    "max_depth": [10, 20, -1],
    "learning_rate": [0.01, 0.05, 0.1],
    "n_estimators": [100, 200]
}

# Grid Search
grid = GridSearchCV(
    estimator=lgbm,
    param_grid=params,
    scoring='recall',   # VERY IMPORTANT
    cv=3,
    n_jobs=-1
)

# Train
grid.fit(x_train, y_train)

# Best model
best_model = grid.best_estimator_

print("Best Parameters:", grid.best_params_)

y_pred = best_model.predict(x_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# [LightGBM] [Info] Number of positive: 19083, number of negative: 204773
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.062594 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 400
# [LightGBM] [Info] Number of data points in the train set: 223856, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# Best Parameters: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 50}
#               precision    recall  f1-score   support
#
#            0       0.98      0.71      0.82     87649
#            1       0.21      0.81      0.33      8290
#
#     accuracy                           0.72     95939
#    macro avg       0.59      0.76      0.58     95939
# ...

# %%
y_prob = best_model.predict_proba(x_test)[:,1]

y_pred = (y_prob > 0.55).astype(int)

print(f"\n===== {"LightGBM"} =====")
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# ===== LightGBM =====
# Confusion Matrix:
#  [[68388 19261]
#  [ 2244  6046]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86     87649
#            1       0.24      0.73      0.36      8290
#
#     accuracy                           0.78     95939
#    macro avg       0.60      0.75      0.61     95939
# weighted avg       0.91      0.78      0.82     95939

# %% [markdown]
# # Deployment

# %%
# ── Model Persistence ──
import joblib
import os

# Save the tuned LightGBM model
joblib.dump(best_model, 'lgbm_heart_model.pkl')
print('✅ Model saved → lgbm_heart_model.pkl')

# Save the feature list (used by Streamlit app to align columns)
joblib.dump(features, 'feature_names.pkl')
print('✅ Feature names saved → feature_names.pkl')

# Save the optimized decision threshold
joblib.dump(0.53, 'threshold.pkl')
print('✅ Threshold saved → threshold.pkl')

# Save the IQR bounds for outlier capping (needed in Streamlit preprocessing)
continuous_cols = ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']
iqr_bounds = {}
df_original = pd.read_csv('Heart.csv')
df_original.drop_duplicates(inplace=True)
for col in continuous_cols:
    Q1 = df_original[col].quantile(0.25)
    Q3 = df_original[col].quantile(0.75)
    IQR = Q3 - Q1
    iqr_bounds[col] = {
        'lb': Q1 - 1.5 * IQR,
        'ub': Q3 + 1.5 * IQR
    }
joblib.dump(iqr_bounds, 'iqr_bounds.pkl')
print('✅ IQR bounds saved → iqr_bounds.pkl')

print(f'\n📦 All artifacts saved to: {os.getcwd()}')
print(f'   Features used: {features}')
# Out:
# ✅ Model saved → lgbm_heart_model.pkl
# ✅ Feature names saved → feature_names.pkl
# ✅ Threshold saved → threshold.pkl
# ✅ IQR bounds saved → iqr_bounds.pkl
#
# 📦 All artifacts saved to: D:\Python_JupyterNotebook\Projects\PITP
#    Features used: ['GenHealth', 'IS_Stroke', 'PhysicalHealth', 'AgeCategory', 'DiseaseCount', 'Age_Disease', 'TotalRisk', 'IS_MALE', 'IS_DiffWalking', 'IS_Diabetic', 'IS_Smoking', 'IS_PhysicalActivity', 'LifestyleRisk', 'BMI', 'MentalHealth', 'SleepTime', 'HealthScore']
